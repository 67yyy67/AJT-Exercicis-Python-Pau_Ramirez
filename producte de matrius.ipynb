# %%
A = [[1, 2, 3],
     [0, 0, 2],
     [2, 1, 1]]
B = [[5, 0, 1],
     [1, 1, 1],
     [2, 3, 1]]
C = []
for a in range(len(A)):
    C.append([])
if len(A) == len(B[0]):
    for a in range(len(A)):
        for b in A[a]:
            

else:
    print("no multiplicables")
# Out:
# [[], [], []]
